# %%
import bs4 
from bs4 import BeautifulSoup
import urllib.request as urllib_request
from urllib.request import Request, urlopen, urlretrieve
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError
import pandas as pd
import re
import time

print("BeautifulSoup ->", bs4.__version__)
print("urllib ->", urllib_request.__version__)
print("pandas ->", pd.__version__)
# Out:
# BeautifulSoup -> 4.11.1
# urllib -> 3.10
# pandas -> 1.5.2

# %%
#Declaring card variables
cards = []
parking = []
bedroom = []
street = []
neighborhood = []

# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=1&transacao=venda&onde=,Rio%20de%20Janeiro,Rio%20de%20Janeiro,,,,,city,BR%3ERio%20de%20Janeiro%3ENULL%3ERio%20de%20Janeiro,-22.786856,-43.313089,

#Setting number of pages to be scrapped. Zap Imoveis shwos 359.321 imoveis available for purchase in Rio de Janeiro - RJ. 
# With 30 results being displayed per page, this would result in 11.978 pages to be scrapped. 
# However, the results only show up to page 100.
pages = int(100)

##Going over all website pages
for i in range(pages):
    i = i+1
    ##Getting HTML for that page
    response = 'https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=' + str(i) + '&version=v2'
    print(f"{response}+for page+{str(i)}")
    headers = {'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

    request = Request(response,headers = headers)

    try:
        response = urlopen(request)
        print(response.status) 
        html = response.read().decode('utf-8')
        soup = BeautifulSoup(html, 'html.parser')
    except HTTPError as e:
        print(e.status, e.reason) 
    except URLError as e:
        print(e.reason)
          
    #Getting tags
    posts = soup.find('div', {'class': 'listing-wrapper__content'}).findAll('div', class_='result-card')
    
    #Filling in card information using the posts
    for post in posts:
        card = {}
        
        # address
        address = post.find('h2',{'class':'l-text l-u-color-neutral-28 l-text--variant-heading-small l-text--weight-medium card__address'})
        if address == None:
            card['neighborhood'], card['city'] = str('N/A', 'N/A')
        else :
            card['neighborhood'], card['city'], *outro = address.get_text().replace('\n','').replace('  ','').split(',')

        # description
        description = post.find('p', {'class': 'l-text l-u-color-neutral-44 l-text--variant-body-small l-text--weight-regular card__description'})
        if description == None:
            card['description'] = str('N/A')
        else :
            card['description'] = str(description.get_text().replace('-',' ').replace('\n',''))

         # price
        price = post.find('p', class_='l-text l-u-color-neutral-28 l-text--variant-heading-small l-text--weight-bold undefined')
        if price is None:
            card['price'] = 0
        else:
            card['price'] = price.get_text().replace('R$', '').replace('\n', '').replace('.', '')

        #taxes
        iptu = post.find('p',{'class':'l-text l-u-color-neutral-44 l-text--variant-body-small l-text--weight-regular undefined'})
        if iptu == None:
            card['condominio'] = int('0')
            card['iptu'] = int('0')
        else:
            card['condominio'] = int(iptu.get_text().split('|')[0].replace('R$','').replace('\n','').replace('.','').replace(' ','').replace('Cond',''))
            card['iptu'] = int(iptu.get_text().split('|')[1].replace('R$','').replace('\n','').replace('.','').replace(' ','').replace('IPTU',''))

        #area
        area = post.find('span',{'itemprop':'floorSize'})
        if area == None:
            card['area(m2)'] = int(30)
        else :
            card['area(m2)'] = int(area.get_text().replace(' ','').replace('\n','').replace('m²',''))


        #bedrooms
        bedrooms = post.find('span',{'itemprop':'numberOfRooms'})
        if bedrooms == None:
            card['bedrooms'] = int(1)
        else :
            card['bedrooms'] = int(quartos.get_text().replace(' ','').replace('\n',''))

        #suite    
        if re.search("suite|suíte|suites|suítes", card['description'].lower()) != None:
            card['suite'] =  int(1)
        else:
            card['suite'] =  int(0)  


        #bathrooms
        bathrooms = post.find('span',{'itemprop':'numberOfBathroomsTotal'})
        if bathrooms == None:
            card['bathrooms'] = int(1)
        else :
            card['bathrooms'] = int(bathrooms.get_text().replace(' ','').replace('\n',''))


        #garage
        garage = post.find('li',{'class':'feature__item text-small js-parking-spaces'})
        if garage == None:
            card['garage'] = int(0)
        else :
            card['garage'] = int(garage.get_text().replace(' ','').replace('\n',''))


        #Link
        link = post.find('a', {'class':'result-card'})
        if link == None:
            card['link'] = str('Não disponivel')
        else:
            card['link'] = str(link['href'])


        cards.append(card)

zap_bs4 = pd.DataFrame(cards)
print(zap_bs4.isna().sum())
zap_bs4.head(50)
# Out:
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=1&version=v2+for page+1
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=2&version=v2+for page+2
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=3&version=v2+for page+3
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=4&version=v2+for page+4
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=5&version=v2+for page+5
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=6&version=v2+for page+6
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=7&version=v2+for page+7
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=8&version=v2+for page+8
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=9&version=v2+for page+9
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=10&version=v2+for page+10
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=11&version=v2+for page+11
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=12&version=v2+for page+12
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=13&version=v2+for page+13
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=14&version=v2+for page+14
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=15&version=v2+for page+15
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=16&version=v2+for page+16
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=17&version=v2+for page+17
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=18&version=v2+for page+18
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=19&version=v2+for page+19
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=20&version=v2+for page+20
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=21&version=v2+for page+21
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=22&version=v2+for page+22
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=23&version=v2+for page+23
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=24&version=v2+for page+24
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=25&version=v2+for page+25
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=26&version=v2+for page+26
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=27&version=v2+for page+27
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=28&version=v2+for page+28
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=29&version=v2+for page+29
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=30&version=v2+for page+30
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=31&version=v2+for page+31
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=32&version=v2+for page+32
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=33&version=v2+for page+33
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=34&version=v2+for page+34
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=35&version=v2+for page+35
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=36&version=v2+for page+36
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=37&version=v2+for page+37
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=38&version=v2+for page+38
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=39&version=v2+for page+39
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=40&version=v2+for page+40
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=41&version=v2+for page+41
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=42&version=v2+for page+42
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=43&version=v2+for page+43
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=44&version=v2+for page+44
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=45&version=v2+for page+45
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=46&version=v2+for page+46
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=47&version=v2+for page+47
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=48&version=v2+for page+48
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=49&version=v2+for page+49
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=50&version=v2+for page+50
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=51&version=v2+for page+51
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=52&version=v2+for page+52
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=53&version=v2+for page+53
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=54&version=v2+for page+54
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=55&version=v2+for page+55
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=56&version=v2+for page+56
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=57&version=v2+for page+57
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=58&version=v2+for page+58
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=59&version=v2+for page+59
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=60&version=v2+for page+60
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=61&version=v2+for page+61
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=62&version=v2+for page+62
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=63&version=v2+for page+63
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=64&version=v2+for page+64
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=65&version=v2+for page+65
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=66&version=v2+for page+66
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=67&version=v2+for page+67
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=68&version=v2+for page+68
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=69&version=v2+for page+69
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=70&version=v2+for page+70
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=71&version=v2+for page+71
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=72&version=v2+for page+72
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=73&version=v2+for page+73
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=74&version=v2+for page+74
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=75&version=v2+for page+75
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=76&version=v2+for page+76
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=77&version=v2+for page+77
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=78&version=v2+for page+78
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=79&version=v2+for page+79
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=80&version=v2+for page+80
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=81&version=v2+for page+81
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=82&version=v2+for page+82
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=83&version=v2+for page+83
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=84&version=v2+for page+84
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=85&version=v2+for page+85
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=86&version=v2+for page+86
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=87&version=v2+for page+87
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=88&version=v2+for page+88
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=89&version=v2+for page+89
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=90&version=v2+for page+90
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=91&version=v2+for page+91
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=92&version=v2+for page+92
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=93&version=v2+for page+93
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=94&version=v2+for page+94
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=95&version=v2+for page+95
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=96&version=v2+for page+96
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=97&version=v2+for page+97
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=98&version=v2+for page+98
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=99&version=v2+for page+99
# 200
# https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/?pagina=100&version=v2+for page+100
# 200
# neighborhood    0
# city            0
# description     0
# price           0
# condominio      0
# iptu            0
# area(m2)        0
# bedrooms        0
# suite           0
# bathrooms       0
# garage          0
# link            0
# dtype: int64
#                 neighborhood             city  \
# 0                     Centro   Rio de Janeiro
# 1                     Centro   Rio de Janeiro
# 2                     Centro   Rio de Janeiro
# 3   Recreio dos Bandeirantes   Rio de Janeiro
# 4                      Gávea   Rio de Janeiro
# 5   Recreio dos Bandeirantes   Rio de Janeiro
# 6                 Copacabana   Rio de Janeiro
# 7                  Pechincha   Rio de Janeiro
# 8                Laranjeiras   Rio de Janeiro
# 9                   Flamengo   Rio de Janeiro
# 10                Copacabana   Rio de Janeiro
# 11                Copacabana   Rio de Janeiro
# 12            Penha Circular   Rio de Janeiro
# 13                     Gávea   Rio de Janeiro
# 14                   Taquara   Rio de Janeiro
# 15                  Botafogo   Rio de Janeiro
# 16                  Botafogo   Rio de Janeiro
# 17                  Botafogo   Rio de Janeiro
# 18   Freguesia (Jacarepaguá)   Rio de Janeiro
# 19  Recreio dos Bandeirantes   Rio de Janeiro
# 20           Todos os Santos   Rio de Janeiro
# 21  Recreio dos Bandeirantes   Rio de Janeiro
# 22                Copacabana   Rio de Janeiro
# 23                 Itanhangá   Rio de Janeiro
# 24                    Olaria   Rio de Janeiro
# 25                  Sepetiba   Rio de Janeiro
# 26               Jacarepaguá   Rio de Janeiro
# 27            Penha Circular   Rio de Janeiro
# 28                     Bangu   Rio de Janeiro
# 29            Vargem Pequena   Rio de Janeiro
# 30                  Botafogo   Rio de Janeiro
# 31                    Tijuca   Rio de Janeiro
# 32                  Botafogo   Rio de Janeiro
# 33                    Tijuca   Rio de Janeiro
# 34                   Humaitá   Rio de Janeiro
# 35                   Ipanema   Rio de Janeiro
# 36            Vila Valqueire   Rio de Janeiro
# 37                Praça Seca   Rio de Janeiro
# 38  Recreio dos Bandeirantes   Rio de Janeiro
# 39               Jacarepaguá   Rio de Janeiro
print(prettified_html)
"""
# Out:
# "\n# Find the desired div elements\nlisting_content = soup.find('div', {'class': 'listing-wrapper__content'})\nresult_cards = listing_content.find_all('div', class_='result-card')\n\n# Prettify each result card\nprettified_result_cards = [result_card.prettify() for result_card in result_cards]\n\n# Join the prettified result cards into a single string\nprettified_html = '\n'.join(prettified_result_cards)\n\nprint(prettified_html)\n"

# %%
zap_bs4.to_csv('./dataset/zap/zap_bs4.csv', sep=';' , index=False, encoding='utf-8-sig')
zap_bs4
# Out:
#                   neighborhood             city  \
# 0                       Centro   Rio de Janeiro
# 1                       Centro   Rio de Janeiro
# 2                       Centro   Rio de Janeiro
# 3     Recreio dos Bandeirantes   Rio de Janeiro
# 4                        Gávea   Rio de Janeiro
# ...                        ...              ...
# 1495           Jardim Botânico   Rio de Janeiro
# 1496                  Flamengo   Rio de Janeiro
# 1497                Copacabana   Rio de Janeiro
# 1498                    Tijuca   Rio de Janeiro
# 1499           Barra da Tijuca   Rio de Janeiro
#
#                                             description     price  condominio  \
# 0     UM CHARMOSO EDIFÍCIO HISTÓRICO, COMPLETAMENTE ...    367000           0
# 1     O CENTRO DO RIO ESTÁ SEREQUALIFICANDO. MORAR N...    290000           0
# 2     Economia criativa e inovação. Esses são os pil...    490000           0
# 3     Excelente apartamento de frente em uma das mel...    800000         838
# 4     (Código: 30466, Travessa Madre Jacinta)   Loca...   2690000        2600
# ...                                                 ...       ...         ...
# 1495  O Serena Jardim Botânico é um empreendimento e...    648500           0
# 1496  Privilégio Imóveis Vende. Excelente apartament...    870000         835
# 1497  Apartamento de 2 quartos com armários, sala , ...    540000           0
# 1498  Apartamento à Venda   Tijuca, 2 Quartos, 86 m2...         0         350
# 1499  Aconchegante apartamento à venda no condomínio...   1090000        1100
#
#       iptu  area(m2)  bedrooms  suite  bathrooms  garage  \
# 0        0        30         1      0          1       0
# 1        0        30         1      0          1       0
# 2        0        30         1      0          1       0
# 3     2545        30         1      1          1       0
# 4      505        30         1      1          1       0
# ...    ...       ...       ...    ...        ...     ...
# 1495     0        30         1      0          1       0
# 1496  1980        30         1      1          1       0
# 1497  2104        30         1      0          1       0
# 1498   117        30         1      0          1       0
# 1499  4469        30         1      1          1       0
#
#                                                    link
# 0     https://www.zapimoveis.com.br/lancamento/venda...
# 1     https://www.zapimoveis.com.br/lancamento/venda...
# 2     https://www.zapimoveis.com.br/lancamento/venda...
# 3     https://www.zapimoveis.com.br/imovel/venda-apa...
# 4     https://www.zapimoveis.com.br/imovel/venda-apa...
# ...                                                 ...
# 1495  https://www.zapimoveis.com.br/imovel/venda-apa...
# 1496  https://www.zapimoveis.com.br/imovel/venda-apa...
# 1497  https://www.zapimoveis.com.br/imovel/venda-apa...
# 1498  https://www.zapimoveis.com.br/imovel/venda-apa...
# 1499  https://www.zapimoveis.com.br/imovel/venda-apa...
#
# [1500 rows x 12 columns]
