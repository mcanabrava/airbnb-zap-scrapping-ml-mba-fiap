# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
file_path = 'dataset/airbnb/listings.csv'
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   17878   https://www.airbnb.com/rooms/17878  20230328184454   2023-03-29
# 1  200568  https://www.airbnb.com/rooms/200568  20230328184454   2023-03-29
# 2  202778  https://www.airbnb.com/rooms/202778  20230328184454   2023-03-29
# 3   24480   https://www.airbnb.com/rooms/24480  20230328184454   2023-03-29
# 4  203674  https://www.airbnb.com/rooms/203674  20230328184454   2023-03-29
# 5  342874  https://www.airbnb.com/rooms/342874  20230328184454   2023-03-29
# 6   25026   https://www.airbnb.com/rooms/25026  20230328184454   2023-03-29
# 7  344463  https://www.airbnb.com/rooms/344463  20230328184454   2023-03-29
# 8   35764   https://www.airbnb.com/rooms/35764  20230328184454   2023-03-29
# 9  346694  https://www.airbnb.com/rooms/346694  20230328184454   2023-03-28
#
#         source                                               name  \
# ...

# %%
df['price'] = df['price'].str.replace(',', '')

df.head(300)
# Out:
#          id                          listing_url       scrape_id last_scraped  \
# 0     17878   https://www.airbnb.com/rooms/17878  20230328184454   2023-03-29
# 1    200568  https://www.airbnb.com/rooms/200568  20230328184454   2023-03-29
# 2    202778  https://www.airbnb.com/rooms/202778  20230328184454   2023-03-29
# 3     24480   https://www.airbnb.com/rooms/24480  20230328184454   2023-03-29
# 4    203674  https://www.airbnb.com/rooms/203674  20230328184454   2023-03-29
# 5    342874  https://www.airbnb.com/rooms/342874  20230328184454   2023-03-29
# 6     25026   https://www.airbnb.com/rooms/25026  20230328184454   2023-03-29
# 7    344463  https://www.airbnb.com/rooms/344463  20230328184454   2023-03-29
# 8     35764   https://www.airbnb.com/rooms/35764  20230328184454   2023-03-29
# 9    346694  https://www.airbnb.com/rooms/346694  20230328184454   2023-03-28
# 10   210173  https://www.airbnb.com/rooms/210173  20230328184454   2023-03-29
# ...

# %%
file_path = 'dataset/airbnb/listings.csv'
df.to_csv(file_path, index=False)

# %%
file_path = 'dataset/airbnb/calendar.csv'
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       17878  2023-03-29         f  $350.00        $350.00             5.0
# 1       17878  2023-03-30         f  $350.00        $350.00             5.0
# 2       17878  2023-03-31         f  $350.00        $350.00             5.0
# 3       17878  2023-04-01         f  $350.00        $350.00             5.0
# 4       17878  2023-04-02         f  $350.00        $350.00             5.0
# 5       17878  2023-04-03         f  $350.00        $350.00             5.0
# 6       17878  2023-04-04         f  $350.00        $350.00             5.0
# 7       17878  2023-04-05         f  $350.00        $350.00             5.0
# 8       17878  2023-04-06         f  $350.00        $350.00             5.0
# 9       17878  2023-04-07         f  $350.00        $350.00             5.0
#
#    maximum_nights
# 0            28.0
# 1            28.0
# 2            28.0
# 3            28.0
# 4            28.0
# ...

# %%
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace(',', '')
df['adjusted_price'] = df['adjusted_price'].str.replace(',', '')
df['adjusted_price'] = df['adjusted_price'].str.replace('$', '')

df.head(300)
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_7644\3060756488.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$', '')
# C:\Users\marce\AppData\Local\Temp\ipykernel_7644\3060756488.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['adjusted_price'] = df['adjusted_price'].str.replace('$', '')
#      listing_id        date available   price adjusted_price  minimum_nights  \
# 0         17878  2023-03-29         f  350.00         350.00             5.0
# 1         17878  2023-03-30         f  350.00         350.00             5.0
# 2         17878  2023-03-31         f  350.00         350.00             5.0
# ...

# %%
file_path = 'dataset/airbnb/calendar.csv'
df.to_csv(file_path, index=False)
